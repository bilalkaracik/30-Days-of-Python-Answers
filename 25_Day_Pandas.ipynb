# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('hacker_news.csv')
df = data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20100 entries, 0 to 20099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20100 non-null  int64
#  1   title         20100 non-null  object
#  2   url           17660 non-null  object
#  3   num_points    20100 non-null  int64
#  4   num_comments  20100 non-null  int64
#  5   author        20100 non-null  object
#  6   created_at    20100 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
data.head()
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  10975351  How to Use Open Source and Shut the Fuck Up at...
# 2  11964716  Florida DJs May Face Felony for April Fools' W...
# 3  11919867       Technology ventures: From Idea to Enterprise
# 4  10301696  Note by Note: The Making of Steinway L1037 (2007)
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://hueniverse.com/2016/01/26/how-to-use-op...          39
# 2  http://www.thewire.com/entertainment/2013/04/f...           2
# 3  https://www.amazon.com/Technology-Ventures-Ent...           3
# 4  http://www.nytimes.com/2007/11/07/movies/07ste...           8
#
#    num_comments      author       created_at
# 0            52    ne0phyte   8/4/2016 11:52
# 1            10      josep2  1/26/2016 19:30
# 2             1    vezycash  6/23/2016 22:20
# ...

# %%
data.tail()
# Out:
#              id                                              title  \
# 20095  12379592  How Purism Avoids Intels Active Management Tec...
# 20096  10339284          YC Application Translated and Broken Down
# 20097  10824382  Microkernels are slow and Elvis didn't do no d...
# 20098  10739875                      How Product Hunt really works
# 20099  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 20095  https://puri.sm/philosophy/how-purism-avoids-i...          10
# 20096  https://medium.com/@zreitano/the-yc-applicatio...           4
# 20097  http://blog.darknedgy.net/technology/2016/01/0...         169
# 20098  https://medium.com/@benjiwheeler/how-product-h...         695
# 20099              https://github.com/jmcarp/robobrowser         182
#
#        num_comments         author        created_at
# 20095             6  AdmiralAsshat    8/29/2016 2:22
# ...

# %%
first_five_rows = df.head()

# %%
first_five_rows
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  10975351  How to Use Open Source and Shut the Fuck Up at...
# 2  11964716  Florida DJs May Face Felony for April Fools' W...
# 3  11919867       Technology ventures: From Idea to Enterprise
# 4  10301696  Note by Note: The Making of Steinway L1037 (2007)
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://hueniverse.com/2016/01/26/how-to-use-op...          39
# 2  http://www.thewire.com/entertainment/2013/04/f...           2
# 3  https://www.amazon.com/Technology-Ventures-Ent...           3
# 4  http://www.nytimes.com/2007/11/07/movies/07ste...           8
#
#    num_comments      author       created_at
# 0            52    ne0phyte   8/4/2016 11:52
# 1            10      josep2  1/26/2016 19:30
# 2             1    vezycash  6/23/2016 22:20
# ...

# %%
last_five_rows = df.tail()

# %%
last_five_rows
# Out:
#              id                                              title  \
# 20095  12379592  How Purism Avoids Intels Active Management Tec...
# 20096  10339284          YC Application Translated and Broken Down
# 20097  10824382  Microkernels are slow and Elvis didn't do no d...
# 20098  10739875                      How Product Hunt really works
# 20099  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 20095  https://puri.sm/philosophy/how-purism-avoids-i...          10
# 20096  https://medium.com/@zreitano/the-yc-applicatio...           4
# 20097  http://blog.darknedgy.net/technology/2016/01/0...         169
# 20098  https://medium.com/@benjiwheeler/how-product-h...         695
# 20099              https://github.com/jmcarp/robobrowser         182
#
#        num_comments         author        created_at
# 20095             6  AdmiralAsshat    8/29/2016 2:22
# ...

# %%
titles = df.columns

# %%
titles
# Out:
# Index(['id', 'title', 'url', 'num_points', 'num_comments', 'author',
#        'created_at'],
#       dtype='object')

# %%
pd.Series(titles)
# Out:
# 0              id
# 1           title
# 2             url
# 3      num_points
# 4    num_comments
# 5          author
# 6      created_at
# dtype: object

# %%
python_titles = df[df['title'].str.contains('Python')]

# %%
python_titles
# Out:
#              id                                              title  \
# 103    10974870                From Python to Lua: Why We Switched
# 104    11244541          Ubuntu 16.04 LTS to Ship Without Python 2
# 145    10963528  Create a GUI Application Using Qt and Python i...
# 197    10716331  How I Solved GCHQ's Xmas Card with Python and ...
# 437    11895088  Unikernel Power Comes to Java, Node.js, Go, an...
# ...         ...                                                ...
# 19598  12061177  David Beazley  Python Concurrency from the Gro...
# 19853  10988468    Ask HN: How to automate Python apps deployment?
# 19863  11738470                          Moving Away from Python 2
# 19981  12524656                      Python vs. Julia Observations
# 19999  11735438  Show HN: Decorating: Animated pulsed for your ...
#
#                                                      url  num_points  \
# 103    https://www.distelli.com/blog/using-lua-for-ou...         243
# ...

# %%
python_titles.shape
# Out:
# (149, 7)

# %%
JavaScript_titles = df[df['title'].str.contains('JavaScript')]

# %%
JavaScript_titles
# Out:
#              id                                              title  \
# 268    12352636   Show HN: Hire JavaScript - Top JavaScript Talent
# 812    10741251  Ask HN: Are there any projects or compilers wh...
# 1047   11343334  If you write JavaScript tools or libraries, bu...
# 1094   10422726  Rollup.js: A next-generation JavaScript module...
# 1163   12461624               V8 JavaScript Engine: V8 Release 5.4
# ...         ...                                                ...
# 19350  11448301    Fotorama, a responsive JavaScript photo gallery
# 19549  12105148                 Another Kind of JavaScript Fatigue
# 19611  12203508  Lonely programmer detective uncovers the Mozil...
# 19886  12552131  Ask HN: Best Practices for CSS in a Modern Jav...
# 20070  12149183  Show HN: Parse recipe ingredients using JavaSc...
#
#                                                      url  num_points  \
# 268                              https://www.hirejs.com/           1
# ...

# %%
JavaScript_titles.shape
# Out:
# (169, 7)
